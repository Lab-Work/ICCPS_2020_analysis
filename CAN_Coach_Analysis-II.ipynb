# %%
import bagpy
from bagpy import bagreader
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt
import numpy as np
from strym import strymread

import warnings
warnings.filterwarnings("ignore")
import ntpath

# %%
DataFolder = "../../PandaData/CanCoachExperiment/"
import glob
csvlist = glob.glob(DataFolder+"*.csv")

# %%
r = strymread(csvlist[0])

# %%
statespace = r.state_space(rate = 20)
# Out:
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3af72bdb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
statespace
# Out:
#                                        Time  speed  distance_covered  accelx  \
# Clock
# 2020-10-13 00:08:16.952913046  1.602548e+09   0.00          0.000000   0.000
# 2020-10-13 00:08:17.002914190  1.602548e+09   0.00          0.000000   0.000
# 2020-10-13 00:08:17.052915573  1.602548e+09   0.00          0.000000   0.000
# 2020-10-13 00:08:17.102916718  1.602548e+09   0.00          0.000000   0.000
# 2020-10-13 00:08:17.152917862  1.602548e+09   0.00          0.000000   0.000
# ...                                     ...    ...               ...     ...
# 2020-10-13 01:04:41.684534311  1.602551e+09  99.68     328665.338722   0.000
# 2020-10-13 01:04:41.734535456  1.602551e+09  99.75     328669.296127   0.000
# 2020-10-13 01:04:41.784536600  1.602551e+09  99.59     328678.174621  -0.095
# 2020-10-13 01:04:41.834537983  1.602551e+09  99.61     328681.380953  -0.195
# 2020-10-13 01:04:41.884539127  1.602551e+09  99.59     328686.450346  -0.195
#
# ...

# %%
fig, ax = strymread.create_fig(statespace.columns.shape[0]-1)
i = 0
for c in statespace.columns:
    if c == 'Time':
        continue
    ax[i].scatter(x = 'Time', y = c, data= statespace, s= 2, c= 'Time', cmap = strymread.sunset)
    ax[i].set_title(c, fontsize = 22)
    ax[i].set_xlabel('Time', fontsize =20)
    ax[i].set_ylabel(c, fontsize = 20)
    i = i + 1

fig.suptitle(ntpath.basename(csvlist[0]), y = 1.001, fontsize = 26)
fig.tight_layout()
fig.show()

# %%
DataFolder = "/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_10_13/"
import glob
csvlist = glob.glob(DataFolder+"*_GPS_*.csv")
import strym
from strym import strymmap
csvlist
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# ['/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_10_13/2020-10-13-09-19-19_5FNYF6H05HB089022_GPS_Messages.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_10_13/2020-10-13-08-16-02_5FNYF6H05HB089022_GPS_Messages.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_10_13/2020-10-13-09-20-55_5FNYF6H05HB089022_GPS_Messages.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_10_13/2020-10-13-13-26-52_5FNYF6H05HB089022_GPS_Messages.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_10_13/2020-10-13-11-03-22_5FNYF6H05HB089022_GPS_Messages.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_10_13/2020-10-13-09-22-24_5FNYF6H05HB089022_GPS_Messages.csv',
# ...

# %%
for csv in csvlist:
    g = strymmap(csv, time_axis = True)
# Out:
# No data was present in the csvfile. Not generating map for the drive.
# GPS signal first acquired at 2020-10-13 15:16:02:300000
#
# Looking for [chromedriver 86.0.4240.22 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/86.0.4240.22/linux64/chromedriver]
# No data was present in the csvfile. Not generating map for the drive.
# GPS signal first acquired at 2020-10-13 20:26:52:500000
#
# Looking for [chromedriver 86.0.4240.22 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/86.0.4240.22/linux64/chromedriver]
# GPS signal first acquired at 2020-10-13 18:03:22:600000
#
# Looking for [chromedriver 86.0.4240.22 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/86.0.4240.22/linux64/chromedriver]
# GPS signal first acquired at 2020-10-13 16:22:23:800000
#
# Looking for [chromedriver 86.0.4240.22 linux64] driver in cache
# ...

# %%
g.plotroute(interactive=False)
# Out:
# <PIL.Image.Image image mode=RGBA size=1800x800 at 0x7F631E113710>
# GMap(id='2143', ...)

# %%
from bokeh.palettes import Plasma256 as palette

# %%
palette[:128]
# Out:
# ['#0C0786',
#  '#100787',
#  '#130689',
#  '#15068A',
#  '#18068B',
#  '#1B068C',
#  '#1D068D',
#  '#1F058E',
#  '#21058F',
#  '#230590',
#  '#250591',
#  '#270592',
#  '#290593',
#  '#2B0594',
#  '#2D0494',
#  '#2F0495',
#  '#310496',
#  '#330497',
#  '#340498',
#  '#360498',
#  '#380499',
#  '#3A049A',
#  '#3B039A',
#  '#3D039B',
#  '#3F039C',
#  '#40039C',
#  '#42039D',
#  '#44039E',
#  '#45039E',
#  '#47029F',
#  '#49029F',
#  '#4A02A0',
#  '#4C02A1',
#  '#4E02A1',
#  '#4F02A2',
#  '#5101A2',
#  '#5201A3',
#  '#5401A3',
#  '#5601A3',
#  '#5701A4',
#  '#5901A4',
#  '#5A00A5',
#  '#5C00A5',
#  '#5E00A5',
#  '#5F00A6',
#  '#6100A6',
#  '#6200A6',
#  '#6400A7',
#  '#6500A7',
#  '#6700A7',
#  '#6800A7',
#  '#6A00A7',
#  '#6C00A8',
#  '#6D00A8',
#  '#6F00A8',
#  '#7000A8',
#  '#7200A8',
#  '#7300A8',
#  '#7500A8',
#  '#7601A8',
#  '#7801A8',
#  '#7901A8',
#  '#7B02A8',
#  '#7C02A7',
#  '#7E03A7',
#  '#7F03A7',
#  '#8104A7',
#  '#8204A7',
#  '#8405A6',
#  '#8506A6',
#  '#8607A6',
# ...
